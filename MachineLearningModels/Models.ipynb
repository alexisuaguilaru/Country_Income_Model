# %% [markdown]
# <div style="
#     display: flex;
#     justify-content: center;
#     align-items: center;
# ">
#     <img src="data:image/png;base64,..." alt="portada" style="width: 50%;">
# </div>

# %% [markdown]
# # Introduction
